# %% [markdown]
# <a href="https://colab.research.google.com/github/revak18/Science-Fair-2024/blob/main/FTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
FTM_fires = pd.read_csv('/content/drive/MyDrive/FTM Science Fair Data/FTM_FIRES.csv')
FTM_fires.head()
# Out:
#                     YrFireName                  Fire Dataset    N  yr_fire  \
# 0         1981 - Manning Basin         Manning Basin   Brown  465     1981
# 1             1981 - Snowdrift             Snowdrift   Brown  481     1981
# 2           1981 - Steep Creek           Steep Creek   Brown  323     1981
# 3  1982 - SEKI 69 or 74 Reburn  SEKI 69 or 74 Reburn     NPS    9     1982
# 4                  1983 - Oops                  Oops    Hood  170     1983
#
#     Latitude   Longitude  Elevation  month_fire  day_fire Fire_type  \
# 0  42.602739 -111.119003       2028         9.0      22.0        RX
# 1  42.549037 -111.226913       2860         9.0      22.0        RX
# 2  42.272226 -110.556666       2368         9.0      28.0      Wild
# 3  36.706663 -118.920540       1903         NaN       NaN       NaN
# 4  48.359752 -116.752536       1303        10.0       NaN      Wild
#
#         State    Sample_design   Plot_size_ha   Threshold_diameter_cm  \
# ...

# %%
FTM_trees = pd.read_csv('/content/drive/MyDrive/FTM Science Fair Data/FTM_TREES.csv')
FTM_trees.head()
for column in FTM_trees.columns:
    print(column)
# Out:
# YrFireName
# Species
# Dataset
# Times_burned
# ID
# Plot
# TreeNum
# Unit
# Genus
# Species_name
# Subspecies
# Genus_species
# DBH_cm
# DRC_cm
# HT_m
# HCB_pre
# CR_pre
# CC
# VR
# CL_m
# yr0status
# yr1status
# yr2status
# yr3status
# yr4status
# yr5status
# yr6status
# yr7status
# yr8status
# yr9status
# yr10status
# HCB_post
# CR_post
# CSH_m
# CLS_m
# CLK_m
# CLS_percent
# CLK_percent
# CVS_percent
# CVK_percent
# CVC_percent
# CBS
# BCHA_m
# BCHM_m
# BCH_percent
# BCA
# CKR
# GCA
# GIR_percent
# DMR
# BTL
# AB
# DFB
# FEN
# IPS
# MPB
# RPB
# RTB
# SB
# WPB
# WB
# SPB
# CVS_percent_source
# CVK_percent_source
# <ipython-input-8-e7fc42da2649>:1: DtypeWarning: Columns (4,5,6,7,10,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   FTM_trees = pd.read_csv('/content/drive/MyDrive/FTM Science Fair Data/FTM_TREES.csv')
